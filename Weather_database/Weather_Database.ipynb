# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time 

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 746

# %%
#Import dependencies
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    time.sleep(1)
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | podyuga
# Processing Record 4 of Set 1 | saint-philippe
# Processing Record 5 of Set 1 | one hundred mile house
# City not found. Skipping...
# Processing Record 6 of Set 1 | yar-sale
# Processing Record 7 of Set 1 | jamestown
# Processing Record 8 of Set 1 | aksha
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | anadyr
# Processing Record 11 of Set 1 | vaini
# Processing Record 12 of Set 1 | shchelyayur
# City not found. Skipping...
# Processing Record 13 of Set 1 | nanortalik
# Processing Record 14 of Set 1 | sao filipe
# Processing Record 15 of Set 1 | wagar
# Processing Record 16 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 17 of Set 1 | ilebo
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | grindavik
# Processing Record 22 of Set 1 | kikwit
# Processing Record 23 of Set 1 | fort nelson
# Processing Record 24 of Set 1 | tuktoyaktuk
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | luderitz
# Processing Record 27 of Set 1 | pangnirtung
# Processing Record 28 of Set 1 | pokhara
# Processing Record 29 of Set 1 | port lincoln
# Processing Record 30 of Set 1 | vostok
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | kaitangata
# Processing Record 33 of Set 1 | zabol
# Processing Record 34 of Set 1 | chunskiy
# Processing Record 35 of Set 1 | dauphin
# Processing Record 36 of Set 1 | tasiilaq
# Processing Record 37 of Set 1 | kahului
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | atuona
# Processing Record 40 of Set 1 | dingle
# Processing Record 41 of Set 1 | severo-kurilsk
# Processing Record 42 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 1 | bambous virieux
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | cape town
# Processing Record 46 of Set 1 | chaa-khol
# City not found. Skipping...
# Processing Record 47 of Set 1 | nola
# Processing Record 48 of Set 1 | pevek
# Processing Record 49 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 50 of Set 1 | mahebourg
# Processing Record 1 of Set 2 | kimbe
# Processing Record 2 of Set 2 | khatanga
# Processing Record 3 of Set 2 | bandar-e lengeh
# Processing Record 4 of Set 2 | cap malheureux
# Processing Record 5 of Set 2 | maragogi
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | port-gentil
# Processing Record 8 of Set 2 | sioux falls
# Processing Record 9 of Set 2 | mataura
# Processing Record 10 of Set 2 | avarua
# Processing Record 11 of Set 2 | georgetown
# Processing Record 12 of Set 2 | hermanus
# Processing Record 13 of Set 2 | san patricio
# Processing Record 14 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 2 | sitio novo do tocantins
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | nata
# Processing Record 18 of Set 2 | bluff
# Processing Record 19 of Set 2 | arlit
# Processing Record 20 of Set 2 | tupaciguara
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | djougou
# Processing Record 23 of Set 2 | madawaska
# Processing Record 24 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 2 | saskylakh
# Processing Record 26 of Set 2 | hasaki
# Processing Record 27 of Set 2 | tazovskiy
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | marshfield
# Processing Record 30 of Set 2 | durban
# Processing Record 31 of Set 2 | havoysund
# Processing Record 32 of Set 2 | casper
# Processing Record 33 of Set 2 | iqaluit
# Processing Record 34 of Set 2 | gurskoye
# City not found. Skipping...
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | makakilo city
# Processing Record 38 of Set 2 | ambilobe
# Processing Record 39 of Set 2 | dong xoai
# Processing Record 40 of Set 2 | skaudvile
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | kismayo
# Processing Record 43 of Set 2 | ostrovnoy
# Processing Record 44 of Set 2 | the valley
# Processing Record 45 of Set 2 | bengkulu
# Processing Record 46 of Set 2 | kashan
# Processing Record 47 of Set 2 | sirjan
# Processing Record 48 of Set 2 | altay
# Processing Record 49 of Set 2 | hobart
# Processing Record 50 of Set 2 | goderich
# Processing Record 1 of Set 3 | aspindza
# Processing Record 2 of Set 3 | bata
# Processing Record 3 of Set 3 | kieta
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | san pedro
# Processing Record 7 of Set 3 | saint george
# Processing Record 8 of Set 3 | north bend
# Processing Record 9 of Set 3 | egvekinot
# Processing Record 10 of Set 3 | musoma
# Processing Record 11 of Set 3 | carnarvon
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | vila franca do campo
# Processing Record 14 of Set 3 | albany
# Processing Record 15 of Set 3 | hamilton
# Processing Record 16 of Set 3 | castro
# Processing Record 17 of Set 3 | lima
# Processing Record 18 of Set 3 | safaga
# Processing Record 19 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 3 | laredo
# Processing Record 22 of Set 3 | lebu
# Processing Record 23 of Set 3 | tunduru
# City not found. Skipping...
# Processing Record 24 of Set 3 | aksarka
# Processing Record 25 of Set 3 | airai
# Processing Record 26 of Set 3 | senanga
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | markova
# Processing Record 30 of Set 3 | laguna
# Processing Record 31 of Set 3 | svetlyy
# Processing Record 32 of Set 3 | uusikaupunki
# Processing Record 33 of Set 3 | northam
# Processing Record 34 of Set 3 | puerto montt
# Processing Record 35 of Set 3 | gamba
# Processing Record 36 of Set 3 | galiwinku
# City not found. Skipping...
# Processing Record 37 of Set 3 | esmeraldas
# Processing Record 38 of Set 3 | alakurtti
# Processing Record 39 of Set 3 | okhotsk
# Processing Record 40 of Set 3 | hualmay
# Processing Record 41 of Set 3 | celestun
# Processing Record 42 of Set 3 | shahrud
# Processing Record 43 of Set 3 | gazli
# Processing Record 44 of Set 3 | omboue
# Processing Record 45 of Set 3 | tiksi
# Processing Record 46 of Set 3 | waipawa
# Processing Record 47 of Set 3 | mar del plata
# Processing Record 48 of Set 3 | semey
# Processing Record 49 of Set 3 | el wasta
# City not found. Skipping...
# Processing Record 50 of Set 3 | podbelsk
# City not found. Skipping...
# Processing Record 1 of Set 4 | salalah
# Processing Record 2 of Set 4 | kodiak
# Processing Record 3 of Set 4 | san cristobal
# Processing Record 4 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 4 | victoria
# Processing Record 6 of Set 4 | ordu
# Processing Record 7 of Set 4 | east london
# Processing Record 8 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 4 | lodwar
# Processing Record 10 of Set 4 | mountain home
# Processing Record 11 of Set 4 | bandeirantes
# Processing Record 12 of Set 4 | nanakuli
# Processing Record 13 of Set 4 | amapa
# Processing Record 14 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 15 of Set 4 | morros
# Processing Record 16 of Set 4 | new norfolk
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | mbamba
# Processing Record 19 of Set 4 | yellowknife
# Processing Record 20 of Set 4 | pacific grove
# Processing Record 21 of Set 4 | saldanha
# Processing Record 22 of Set 4 | hulan
# Processing Record 23 of Set 4 | kaseda
# Processing Record 24 of Set 4 | tual
# Processing Record 25 of Set 4 | erenhot
# Processing Record 26 of Set 4 | nikolskoye
# Processing Record 27 of Set 4 | sao joao da barra
# Processing Record 28 of Set 4 | dhidhdhoo
# Processing Record 29 of Set 4 | olafsvik
# Processing Record 30 of Set 4 | kenai
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | gangotri
# City not found. Skipping...
# Processing Record 33 of Set 4 | sault sainte marie
# Processing Record 34 of Set 4 | yarada
# Processing Record 35 of Set 4 | saint anthony
# Processing Record 36 of Set 4 | todos santos
# Processing Record 37 of Set 4 | nome
# Processing Record 38 of Set 4 | cherskiy
# Processing Record 39 of Set 4 | boende
# Processing Record 40 of Set 4 | camacha
# Processing Record 41 of Set 4 | brae
# Processing Record 42 of Set 4 | sisimiut
# Processing Record 43 of Set 4 | lorengau
# Processing Record 44 of Set 4 | savannah bight
# Processing Record 45 of Set 4 | constitucion
# Processing Record 46 of Set 4 | hithadhoo
# Processing Record 47 of Set 4 | port hardy
# Processing Record 48 of Set 4 | kavaratti
# Processing Record 49 of Set 4 | leningradskiy
# Processing Record 50 of Set 4 | chapais
# Processing Record 1 of Set 5 | hit
# Processing Record 2 of Set 5 | ribeira grande
# Processing Record 3 of Set 5 | bandarban
# Processing Record 4 of Set 5 | port alfred
# Processing Record 5 of Set 5 | chumikan
# Processing Record 6 of Set 5 | clyde river
# Processing Record 7 of Set 5 | noumea
# Processing Record 8 of Set 5 | flinders
# Processing Record 9 of Set 5 | suoyarvi
# Processing Record 10 of Set 5 | san andres
# Processing Record 11 of Set 5 | seoul
# Processing Record 12 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 5 | paita
# Processing Record 14 of Set 5 | atasu
# Processing Record 15 of Set 5 | faanui
# Processing Record 16 of Set 5 | ardmore
# Processing Record 17 of Set 5 | itoman
# Processing Record 18 of Set 5 | namatanai
# Processing Record 19 of Set 5 | tocopilla
# Processing Record 20 of Set 5 | yumen
# Processing Record 21 of Set 5 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 5 | newport
# Processing Record 23 of Set 5 | guerrero negro
# Processing Record 24 of Set 5 | buarcos
# Processing Record 25 of Set 5 | saint-denis
# Processing Record 26 of Set 5 | mapiripan
# Processing Record 27 of Set 5 | whitehorse
# Processing Record 28 of Set 5 | sur
# Processing Record 29 of Set 5 | ayan
# Processing Record 30 of Set 5 | caravelas
# Processing Record 31 of Set 5 | mascote
# Processing Record 32 of Set 5 | vestmannaeyjar
# Processing Record 33 of Set 5 | atar
# Processing Record 34 of Set 5 | shizunai
# Processing Record 35 of Set 5 | saint paul
# Processing Record 36 of Set 5 | mackay
# Processing Record 37 of Set 5 | lagoa
# Processing Record 38 of Set 5 | ambovombe
# Processing Record 39 of Set 5 | porto santo
# Processing Record 40 of Set 5 | ratnagiri
# Processing Record 41 of Set 5 | kasongo-lunda
# Processing Record 42 of Set 5 | roald
# Processing Record 43 of Set 5 | puerto cabezas
# Processing Record 44 of Set 5 | tuatapere
# Processing Record 45 of Set 5 | polovinnoye
# Processing Record 46 of Set 5 | hokitika
# Processing Record 47 of Set 5 | miri
# Processing Record 48 of Set 5 | rozivka
# Processing Record 49 of Set 5 | elizabeth city
# Processing Record 50 of Set 5 | thompson
# Processing Record 1 of Set 6 | lysva
# Processing Record 2 of Set 6 | pecos
# Processing Record 3 of Set 6 | aykino
# Processing Record 4 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 6 | morehead
# Processing Record 6 of Set 6 | katsuura
# Processing Record 7 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 6 | geraldton
# Processing Record 9 of Set 6 | san carlos de bariloche
# Processing Record 10 of Set 6 | klaksvik
# Processing Record 11 of Set 6 | shieli
# Processing Record 12 of Set 6 | roma
# Processing Record 13 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | walvis bay
# Processing Record 15 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 6 | resen
# Processing Record 17 of Set 6 | koutsouras
# Processing Record 18 of Set 6 | arraial do cabo
# Processing Record 19 of Set 6 | ust-ishim
# Processing Record 20 of Set 6 | kyaikto
# Processing Record 21 of Set 6 | marzuq
# Processing Record 22 of Set 6 | bereda
# Processing Record 23 of Set 6 | cabo san lucas
# Processing Record 24 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 25 of Set 6 | eyl
# Processing Record 26 of Set 6 | kallimasia
# City not found. Skipping...
# Processing Record 27 of Set 6 | bethel
# Processing Record 28 of Set 6 | gao
# Processing Record 29 of Set 6 | sao gabriel da cachoeira
# Processing Record 30 of Set 6 | vrises
# Processing Record 31 of Set 6 | gerash
# Processing Record 32 of Set 6 | goksun
# Processing Record 33 of Set 6 | xining
# Processing Record 34 of Set 6 | half moon bay
# Processing Record 35 of Set 6 | aliwal north
# Processing Record 36 of Set 6 | phan thiet
# Processing Record 37 of Set 6 | chaoyang
# Processing Record 38 of Set 6 | naron
# Processing Record 39 of Set 6 | loa janan
# Processing Record 40 of Set 6 | jacqueville
# Processing Record 41 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 42 of Set 6 | charleston
# Processing Record 43 of Set 6 | norman wells
# Processing Record 44 of Set 6 | khalkhal
# Processing Record 45 of Set 6 | euclid
# Processing Record 46 of Set 6 | lasa
# Processing Record 47 of Set 6 | cidreira
# Processing Record 48 of Set 6 | borogontsy
# Processing Record 49 of Set 6 | mundo nuevo
# Processing Record 50 of Set 6 | torbay
# Processing Record 1 of Set 7 | hare bay
# Processing Record 2 of Set 7 | rabo de peixe
# Processing Record 3 of Set 7 | les cayes
# Processing Record 4 of Set 7 | mugan
# Processing Record 5 of Set 7 | nouadhibou
# Processing Record 6 of Set 7 | hearst
# Processing Record 7 of Set 7 | santiago
# Processing Record 8 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 7 | komsomolskiy
# Processing Record 10 of Set 7 | ranong
# Processing Record 11 of Set 7 | astana
# Processing Record 12 of Set 7 | vila velha
# Processing Record 13 of Set 7 | san ignacio
# Processing Record 14 of Set 7 | gambela
# Processing Record 15 of Set 7 | college
# Processing Record 16 of Set 7 | lompoc
# Processing Record 17 of Set 7 | beringovskiy
# Processing Record 18 of Set 7 | buchanan
# Processing Record 19 of Set 7 | ransang
# Processing Record 20 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 7 | tondi
# Processing Record 22 of Set 7 | dasoguz
# Processing Record 23 of Set 7 | shubarshi
# Processing Record 24 of Set 7 | lufkin
# Processing Record 25 of Set 7 | makaha
# Processing Record 26 of Set 7 | tiarei
# Processing Record 27 of Set 7 | barhi
# Processing Record 28 of Set 7 | sambava
# Processing Record 29 of Set 7 | khani
# Processing Record 30 of Set 7 | sorong
# Processing Record 31 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 32 of Set 7 | tchollire
# Processing Record 33 of Set 7 | yulara
# Processing Record 34 of Set 7 | grand gaube
# Processing Record 35 of Set 7 | chuy
# Processing Record 36 of Set 7 | paredon
# Processing Record 37 of Set 7 | akcaabat
# Processing Record 38 of Set 7 | manta
# Processing Record 39 of Set 7 | yatou
# Processing Record 40 of Set 7 | novikovo
# Processing Record 41 of Set 7 | kavieng
# Processing Record 42 of Set 7 | sung noen
# Processing Record 43 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 7 | talas
# Processing Record 45 of Set 7 | rocha
# Processing Record 46 of Set 7 | pisco
# Processing Record 47 of Set 7 | bac lieu
# Processing Record 48 of Set 7 | kuybysheve
# Processing Record 49 of Set 7 | yongzhou
# Processing Record 50 of Set 7 | fortuna
# Processing Record 1 of Set 8 | mount gambier
# Processing Record 2 of Set 8 | baykit
# Processing Record 3 of Set 8 | luanda
# Processing Record 4 of Set 8 | henties bay
# Processing Record 5 of Set 8 | majene
# Processing Record 6 of Set 8 | mullaitivu
# City not found. Skipping...
# Processing Record 7 of Set 8 | kaduna
# Processing Record 8 of Set 8 | asfi
# Processing Record 9 of Set 8 | la macarena
# Processing Record 10 of Set 8 | lavrentiya
# Processing Record 11 of Set 8 | groningen
# Processing Record 12 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 13 of Set 8 | canon city
# Processing Record 14 of Set 8 | la seyne-sur-mer
# Processing Record 15 of Set 8 | gravelbourg
# Processing Record 16 of Set 8 | bathsheba
# Processing Record 17 of Set 8 | lata
# Processing Record 18 of Set 8 | rio gallegos
# Processing Record 19 of Set 8 | deputatskiy
# Processing Record 20 of Set 8 | plouzane
# Processing Record 21 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 22 of Set 8 | tupancireta
# Processing Record 23 of Set 8 | boshnyakovo
# Processing Record 24 of Set 8 | san-pedro
# Processing Record 25 of Set 8 | karratha
# Processing Record 26 of Set 8 | ahipara
# Processing Record 27 of Set 8 | panzhihua
# Processing Record 28 of Set 8 | hakui
# Processing Record 29 of Set 8 | puerto leguizamo
# Processing Record 30 of Set 8 | zhigansk
# Processing Record 31 of Set 8 | seminole
# Processing Record 32 of Set 8 | santo domingo
# Processing Record 33 of Set 8 | sorland
# Processing Record 34 of Set 8 | alpuyeca
# Processing Record 35 of Set 8 | port blair
# Processing Record 36 of Set 8 | norsup
# Processing Record 37 of Set 8 | hami
# Processing Record 38 of Set 8 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 40 of Set 8 | kuching
# Processing Record 41 of Set 8 | shahpura
# Processing Record 42 of Set 8 | namwala
# Processing Record 43 of Set 8 | batagay-alyta
# Processing Record 44 of Set 8 | wajima
# Processing Record 45 of Set 8 | chauk
# Processing Record 46 of Set 8 | coquimbo
# Processing Record 47 of Set 8 | mogocha
# Processing Record 48 of Set 8 | labuan
# Processing Record 49 of Set 8 | manyana
# Processing Record 50 of Set 8 | dabakala
# Processing Record 1 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 9 | temerloh
# Processing Record 3 of Set 9 | monforte de lemos
# Processing Record 4 of Set 9 | russellville
# Processing Record 5 of Set 9 | krasnoselkup
# Processing Record 6 of Set 9 | banda aceh
# Processing Record 7 of Set 9 | dalbandin
# Processing Record 8 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 9 | raudeberg
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | axim
# Processing Record 12 of Set 9 | palmer
# Processing Record 13 of Set 9 | araguacu
# Processing Record 14 of Set 9 | nemuro
# Processing Record 15 of Set 9 | kuusamo
# Processing Record 16 of Set 9 | meulaboh
# Processing Record 17 of Set 9 | oruro
# Processing Record 18 of Set 9 | padang
# Processing Record 19 of Set 9 | codrington
# Processing Record 20 of Set 9 | nerchinskiy zavod
# Processing Record 21 of Set 9 | jumla
# Processing Record 22 of Set 9 | tabora
# Processing Record 23 of Set 9 | vanavara
# Processing Record 24 of Set 9 | charkhi dadri
# Processing Record 25 of Set 9 | sabha
# Processing Record 26 of Set 9 | urumqi
# Processing Record 27 of Set 9 | harper
# Processing Record 28 of Set 9 | sept-iles
# Processing Record 29 of Set 9 | gogrial
# Processing Record 30 of Set 9 | impfondo
# Processing Record 31 of Set 9 | los algarrobos
# Processing Record 32 of Set 9 | mahajanga
# Processing Record 33 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 34 of Set 9 | zhuhai
# Processing Record 35 of Set 9 | mopipi
# Processing Record 36 of Set 9 | fare
# Processing Record 37 of Set 9 | gat
# Processing Record 38 of Set 9 | amahai
# Processing Record 39 of Set 9 | broome
# Processing Record 40 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 9 | unity
# Processing Record 42 of Set 9 | alyangula
# Processing Record 43 of Set 9 | akureyri
# Processing Record 44 of Set 9 | eidsvoll
# Processing Record 45 of Set 9 | pincher creek
# Processing Record 46 of Set 9 | kirakira
# Processing Record 47 of Set 9 | srednekolymsk
# Processing Record 48 of Set 9 | tamalin
# Processing Record 49 of Set 9 | haines junction
# Processing Record 50 of Set 9 | sofia
# Processing Record 1 of Set 10 | aquiraz
# Processing Record 2 of Set 10 | jishui
# Processing Record 3 of Set 10 | belyy yar
# Processing Record 4 of Set 10 | ucluelet
# Processing Record 5 of Set 10 | chegdomyn
# Processing Record 6 of Set 10 | letlhakane
# Processing Record 7 of Set 10 | abu dhabi
# Processing Record 8 of Set 10 | ilulissat
# Processing Record 9 of Set 10 | mangaratiba
# Processing Record 10 of Set 10 | bilibino
# Processing Record 11 of Set 10 | portland
# Processing Record 12 of Set 10 | maltahohe
# Processing Record 13 of Set 10 | honiara
# Processing Record 14 of Set 10 | berlevag
# Processing Record 15 of Set 10 | constantine
# Processing Record 16 of Set 10 | rehoboth
# Processing Record 17 of Set 10 | male
# Processing Record 18 of Set 10 | bartica
# Processing Record 19 of Set 10 | kizema
# Processing Record 20 of Set 10 | xacmaz
# Processing Record 21 of Set 10 | hobyo
# Processing Record 22 of Set 10 | sawakin
# Processing Record 23 of Set 10 | de aar
# Processing Record 24 of Set 10 | namibe
# Processing Record 25 of Set 10 | luau
# Processing Record 26 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 10 | kupang
# Processing Record 28 of Set 10 | igarka
# Processing Record 29 of Set 10 | naze
# Processing Record 30 of Set 10 | tucurui
# Processing Record 31 of Set 10 | araouane
# Processing Record 32 of Set 10 | lagos
# Processing Record 33 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 34 of Set 10 | taoudenni
# Processing Record 35 of Set 10 | general roca
# Processing Record 36 of Set 10 | isla mujeres
# Processing Record 37 of Set 10 | juneau
# Processing Record 38 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 10 | okha
# Processing Record 40 of Set 10 | hovd
# Processing Record 41 of Set 10 | bubaque
# Processing Record 42 of Set 10 | faya
# Processing Record 43 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 10 | buru-un
# City not found. Skipping...
# Processing Record 45 of Set 10 | rovaniemi
# Processing Record 46 of Set 10 | san quintin
# Processing Record 47 of Set 10 | auki
# Processing Record 48 of Set 10 | yerbogachen
# Processing Record 49 of Set 10 | lugazi
# Processing Record 50 of Set 10 | maldonado
# Processing Record 1 of Set 11 | hirara
# Processing Record 2 of Set 11 | jalu
# Processing Record 3 of Set 11 | shingu
# Processing Record 4 of Set 11 | maine-soroa
# Processing Record 5 of Set 11 | oyama
# Processing Record 6 of Set 11 | carlet
# Processing Record 7 of Set 11 | alofi
# Processing Record 8 of Set 11 | vilyuysk
# Processing Record 9 of Set 11 | floro
# Processing Record 10 of Set 11 | solnechnyy
# Processing Record 11 of Set 11 | avera
# Processing Record 12 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 13 of Set 11 | roslyakovo
# Processing Record 14 of Set 11 | ulladulla
# Processing Record 15 of Set 11 | sao jose da coroa grande
# Processing Record 16 of Set 11 | manitouwadge
# Processing Record 17 of Set 11 | carballo
# Processing Record 18 of Set 11 | joshimath
# Processing Record 19 of Set 11 | severo-yeniseyskiy
# Processing Record 20 of Set 11 | zhangye
# Processing Record 21 of Set 11 | santa cruz
# Processing Record 22 of Set 11 | gazojak
# Processing Record 23 of Set 11 | port shepstone
# Processing Record 24 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 25 of Set 11 | richards bay
# Processing Record 26 of Set 11 | macherla
# Processing Record 27 of Set 11 | kungurtug
# Processing Record 28 of Set 11 | bukachacha
# Processing Record 29 of Set 11 | xichang
# Processing Record 30 of Set 11 | maniitsoq
# Processing Record 31 of Set 11 | sri aman
# Processing Record 32 of Set 11 | mangai
# Processing Record 33 of Set 11 | talnakh
# Processing Record 34 of Set 11 | kokoda
# Processing Record 35 of Set 11 | fairbanks
# Processing Record 36 of Set 11 | keetmanshoop
# Processing Record 37 of Set 11 | samarai
# Processing Record 38 of Set 11 | katherine
# Processing Record 39 of Set 11 | broken hill
# Processing Record 40 of Set 11 | sibu
# Processing Record 41 of Set 11 | stornoway
# Processing Record 42 of Set 11 | inhambane
# Processing Record 43 of Set 11 | cabedelo
# Processing Record 44 of Set 11 | ocotal
# Processing Record 45 of Set 11 | kostomuksha
# Processing Record 46 of Set 11 | del rio
# Processing Record 47 of Set 11 | dok kham tai
# Processing Record 48 of Set 11 | dunedin
# Processing Record 49 of Set 11 | baculin
# Processing Record 50 of Set 11 | pokaran
# Processing Record 1 of Set 12 | tyrma
# Processing Record 2 of Set 12 | pierre
# Processing Record 3 of Set 12 | kampil
# Processing Record 4 of Set 12 | sesheke
# Processing Record 5 of Set 12 | matara
# Processing Record 6 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 7 of Set 12 | washougal
# Processing Record 8 of Set 12 | batemans bay
# Processing Record 9 of Set 12 | smithers
# Processing Record 10 of Set 12 | wadi maliz
# Processing Record 11 of Set 12 | ylivieska
# Processing Record 12 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 13 of Set 12 | belmonte
# Processing Record 14 of Set 12 | california city
# Processing Record 15 of Set 12 | mumford
# Processing Record 16 of Set 12 | nioro
# Processing Record 17 of Set 12 | santana do matos
# Processing Record 18 of Set 12 | shitanjing
# Processing Record 19 of Set 12 | bunog
# Processing Record 20 of Set 12 | alice town
# Processing Record 21 of Set 12 | dolzhanskaya
# Processing Record 22 of Set 12 | kushmurun
# Processing Record 23 of Set 12 | rimbey
# Processing Record 24 of Set 12 | simao
# Processing Record 25 of Set 12 | kalmunai
# Processing Record 26 of Set 12 | creteni
# Processing Record 27 of Set 12 | polson
# Processing Record 28 of Set 12 | puerto gaitan
# Processing Record 29 of Set 12 | rawson
# Processing Record 30 of Set 12 | thunder bay
# Processing Record 31 of Set 12 | hay river
# Processing Record 32 of Set 12 | onega
# Processing Record 33 of Set 12 | sain alto
# Processing Record 34 of Set 12 | gigmoto
# Processing Record 35 of Set 12 | qasigiannguit
# Processing Record 36 of Set 12 | gorodets
# Processing Record 37 of Set 12 | eresos
# Processing Record 38 of Set 12 | tomatlan
# Processing Record 39 of Set 12 | laval
# Processing Record 40 of Set 12 | itarema
# Processing Record 41 of Set 12 | ferme-neuve
# Processing Record 42 of Set 12 | krasnozerskoye
# Processing Record 43 of Set 12 | lebedinyy
# Processing Record 44 of Set 12 | porto novo
# Processing Record 45 of Set 12 | suzun
# Processing Record 46 of Set 12 | sechura
# Processing Record 47 of Set 12 | kokopo
# Processing Record 48 of Set 12 | cilegon
# Processing Record 49 of Set 12 | benjamin hill
# Processing Record 50 of Set 12 | koumac
# Processing Record 1 of Set 13 | ambon
# Processing Record 2 of Set 13 | piedras negras
# Processing Record 3 of Set 13 | esperance
# Processing Record 4 of Set 13 | takoradi
# Processing Record 5 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 6 of Set 13 | cam ranh
# Processing Record 7 of Set 13 | lotoshino
# Processing Record 8 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 9 of Set 13 | gelemso
# Processing Record 10 of Set 13 | penzance
# Processing Record 11 of Set 13 | nagato
# Processing Record 12 of Set 13 | recke
# Processing Record 13 of Set 13 | owando
# Processing Record 14 of Set 13 | milledgeville
# Processing Record 15 of Set 13 | tres lagoas
# Processing Record 16 of Set 13 | canguaretama
# Processing Record 17 of Set 13 | labuhan
# Processing Record 18 of Set 13 | jining
# Processing Record 19 of Set 13 | katha
# City not found. Skipping...
# Processing Record 20 of Set 13 | alta floresta
# Processing Record 21 of Set 13 | storforshei
# Processing Record 22 of Set 13 | lexington
# Processing Record 23 of Set 13 | atherton
# Processing Record 24 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 13 | balikpapan
# Processing Record 26 of Set 13 | teseney
# Processing Record 27 of Set 13 | maarianhamina
# Processing Record 28 of Set 13 | kommunisticheskiy
# Processing Record 29 of Set 13 | lakes entrance
# Processing Record 30 of Set 13 | ksenyevka
# City not found. Skipping...
# Processing Record 31 of Set 13 | huangnihe
# Processing Record 32 of Set 13 | havelock
# Processing Record 33 of Set 13 | odweyne
# Processing Record 34 of Set 13 | stare mesto
# Processing Record 35 of Set 13 | andenes
# Processing Record 36 of Set 13 | daxian
# City not found. Skipping...
# Processing Record 37 of Set 13 | dmitriyevka
# Processing Record 38 of Set 13 | nizwa
# Processing Record 39 of Set 13 | havre-saint-pierre
# Processing Record 40 of Set 13 | north fort myers
# Processing Record 41 of Set 13 | puerto madryn
# Processing Record 42 of Set 13 | mount barker
# Processing Record 43 of Set 13 | domoni
# Processing Record 44 of Set 13 | korla
# Processing Record 45 of Set 13 | roebourne
# Processing Record 46 of Set 13 | mehamn
# Processing Record 47 of Set 13 | beira
# Processing Record 48 of Set 13 | zheleznodorozhnyy
# Processing Record 49 of Set 13 | springbok
# Processing Record 50 of Set 13 | sapele
# Processing Record 1 of Set 14 | conceicao do araguaia
# Processing Record 2 of Set 14 | alice springs
# Processing Record 3 of Set 14 | chulumani
# Processing Record 4 of Set 14 | zlobin
# Processing Record 5 of Set 14 | puerto colombia
# Processing Record 6 of Set 14 | sao felix do xingu
# Processing Record 7 of Set 14 | tura
# Processing Record 8 of Set 14 | mana
# Processing Record 9 of Set 14 | gharo
# Processing Record 10 of Set 14 | kultuk
# Processing Record 11 of Set 14 | penicuik
# Processing Record 12 of Set 14 | yokadouma
# Processing Record 13 of Set 14 | kirando
# Processing Record 14 of Set 14 | bluefields
# Processing Record 15 of Set 14 | pudozh
# Processing Record 16 of Set 14 | sohag
# Processing Record 17 of Set 14 | panama city
# Processing Record 18 of Set 14 | nyurba
# Processing Record 19 of Set 14 | tokmak
# Processing Record 20 of Set 14 | qiongshan
# Processing Record 21 of Set 14 | sterling
# Processing Record 22 of Set 14 | gwadar
# Processing Record 23 of Set 14 | safford
# Processing Record 24 of Set 14 | turukhansk
# Processing Record 25 of Set 14 | labrea
# Processing Record 26 of Set 14 | koungheul
# Processing Record 27 of Set 14 | babushkin
# Processing Record 28 of Set 14 | moron
# Processing Record 29 of Set 14 | budesti
# Processing Record 30 of Set 14 | chateaubelair
# Processing Record 31 of Set 14 | waddan
# Processing Record 32 of Set 14 | aklavik
# Processing Record 33 of Set 14 | sobolevo
# Processing Record 34 of Set 14 | nalut
# Processing Record 35 of Set 14 | inirida
# Processing Record 36 of Set 14 | severobaykalsk
# Processing Record 37 of Set 14 | fonte boa
# Processing Record 38 of Set 14 | caldas novas
# Processing Record 39 of Set 14 | yazykovo
# Processing Record 40 of Set 14 | trairi
# Processing Record 41 of Set 14 | khandyga
# Processing Record 42 of Set 14 | cayenne
# Processing Record 43 of Set 14 | burnie
# Processing Record 44 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 14 | tabou
# Processing Record 46 of Set 14 | shumskiy
# Processing Record 47 of Set 14 | marawi
# Processing Record 48 of Set 14 | bandarbeyla
# Processing Record 49 of Set 14 | puerto ayacucho
# Processing Record 50 of Set 14 | isangel
# Processing Record 1 of Set 15 | kapuskasing
# Processing Record 2 of Set 15 | bontang
# Processing Record 3 of Set 15 | tenenkou
# Processing Record 4 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 15 | tarakan
# Processing Record 6 of Set 15 | taltal
# Processing Record 7 of Set 15 | murgab
# Processing Record 8 of Set 15 | kursenai
# Processing Record 9 of Set 15 | miramar
# Processing Record 10 of Set 15 | jiangyou
# Processing Record 11 of Set 15 | commerce
# Processing Record 12 of Set 15 | sedelnikovo
# City not found. Skipping...
# Processing Record 13 of Set 15 | badin
# Processing Record 14 of Set 15 | saint-paul-les-dax
# Processing Record 15 of Set 15 | mukhen
# Processing Record 16 of Set 15 | tilichiki
# Processing Record 17 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 18 of Set 15 | pochutla
# Processing Record 19 of Set 15 | beitbridge
# Processing Record 20 of Set 15 | westport
# Processing Record 21 of Set 15 | gold coast
# Processing Record 22 of Set 15 | wardha
# Processing Record 23 of Set 15 | hudson bay
# Processing Record 24 of Set 15 | winton
# Processing Record 25 of Set 15 | orange cove
# Processing Record 26 of Set 15 | high rock
# Processing Record 27 of Set 15 | hegang
# Processing Record 28 of Set 15 | la esperanza
# Processing Record 29 of Set 15 | maningrida
# Processing Record 30 of Set 15 | ginda
# Processing Record 31 of Set 15 | passos
# Processing Record 32 of Set 15 | canavieiras
# Processing Record 33 of Set 15 | conchas
# Processing Record 34 of Set 15 | bilma
# Processing Record 35 of Set 15 | abu kamal
# Processing Record 36 of Set 15 | margate
# Processing Record 37 of Set 15 | svetlaya
# Processing Record 38 of Set 15 | volga
# Processing Record 39 of Set 15 | kiunga
# Processing Record 40 of Set 15 | los llanos de aridane
# Processing Record 41 of Set 15 | kambove
# Processing Record 42 of Set 15 | cockburn town
# Processing Record 43 of Set 15 | agirish
# Processing Record 44 of Set 15 | tselinnoye
# Processing Record 45 of Set 15 | nador
# Processing Record 46 of Set 15 | sarkand
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Ushuaia      AR -54.8000  -68.3000     46.02        70          40
# 1    Punta Arenas      CL -53.1500  -70.9167     46.42        76          75
# 2         Podyuga      RU  61.0950   40.8647     27.99        77         100
# 3  Saint-Philippe      RE -21.3585   55.7679     75.22        81          23
# 4        Yar-Sale      RU  66.8333   70.8333     15.08        85         100
# 5       Jamestown      US  42.0970  -79.2353     44.02        37           0
# 6           Aksha      RU  50.2814  113.2867     30.20        67          99
# 7      Bredasdorp      ZA -34.5322   20.0403     58.08        93          16
# 8          Anadyr      RU  64.7500  177.4833     23.50        93         100
# 9           Vaini      TO -21.2000 -175.2000     77.16        73          20
#
#    Wind Speed Current Description
# 0       35.68    scattered clouds
# 1       24.16       broken clouds
# 2        5.97     overcast clouds
# 3        6.96          few clouds
# 4        4.83     overcast clouds
# 5       11.50           clear sky
# 6       16.11     overcast clouds
# 7        3.51          few clouds
# 8        4.47                 fog
# 9       10.36          few clouds

# %%
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
