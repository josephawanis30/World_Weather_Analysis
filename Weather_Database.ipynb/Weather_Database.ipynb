# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time 

from citipy import citipy

# %%
#Create a set of 2,000 random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 732

# %%
#Import dependencies
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1
    time.sleep(1)
    
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_description = city_weather['weather'][0]['description']
        
        city_data.append({'City': city.title(),
                          'Country': city_country,
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Current Description': city_description})
    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | castro
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | te anau
# Processing Record 5 of Set 1 | spring hill
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | port hawkesbury
# Processing Record 8 of Set 1 | cape town
# Processing Record 9 of Set 1 | roebourne
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | port lincoln
# Processing Record 12 of Set 1 | new norfolk
# Processing Record 13 of Set 1 | alice springs
# Processing Record 14 of Set 1 | vanimo
# Processing Record 15 of Set 1 | severo-kurilsk
# Processing Record 16 of Set 1 | guerrero negro
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | karaman
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | tasiilaq
# Processing Record 22 of Set 1 | thompson
# Processing Record 23 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | klaksvik
# Processing Record 26 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 1 | tuktoyaktuk
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | mar del plata
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | lorengau
# Processing Record 32 of Set 1 | sao joao da barra
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 1 | makakilo city
# Processing Record 37 of Set 1 | hobart
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | georgetown
# Processing Record 40 of Set 1 | butaritari
# Processing Record 41 of Set 1 | aksu
# Processing Record 42 of Set 1 | manokwari
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | vidim
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | gazojak
# Processing Record 48 of Set 1 | namatanai
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | qaanaaq
# Processing Record 1 of Set 2 | longyearbyen
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | bathsheba
# Processing Record 6 of Set 2 | hambantota
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | dauphin
# Processing Record 10 of Set 2 | onega
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | vladimiro-aleksandrovskoye
# Processing Record 13 of Set 2 | avarua
# Processing Record 14 of Set 2 | ancud
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | hermanus
# Processing Record 17 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 2 | domna
# Processing Record 19 of Set 2 | cockburn town
# Processing Record 20 of Set 2 | shimoda
# Processing Record 21 of Set 2 | mende
# Processing Record 22 of Set 2 | tsienyane
# City not found. Skipping...
# Processing Record 23 of Set 2 | puerto ayora
# Processing Record 24 of Set 2 | qaqortoq
# Processing Record 25 of Set 2 | kaeo
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | sao filipe
# Processing Record 28 of Set 2 | nikolskoye
# Processing Record 29 of Set 2 | faanui
# Processing Record 30 of Set 2 | fairbanks
# Processing Record 31 of Set 2 | chuy
# Processing Record 32 of Set 2 | mbini
# Processing Record 33 of Set 2 | ribeira grande
# Processing Record 34 of Set 2 | olga
# Processing Record 35 of Set 2 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 2 | rosa zarate
# Processing Record 37 of Set 2 | arraial do cabo
# Processing Record 38 of Set 2 | jalingo
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | cherskiy
# Processing Record 41 of Set 2 | upernavik
# Processing Record 42 of Set 2 | pisco
# Processing Record 43 of Set 2 | puerto madryn
# Processing Record 44 of Set 2 | george
# Processing Record 45 of Set 2 | safidon
# Processing Record 46 of Set 2 | barra do corda
# Processing Record 47 of Set 2 | chantilly
# Processing Record 48 of Set 2 | sterling
# Processing Record 49 of Set 2 | bud
# Processing Record 50 of Set 2 | mandla
# Processing Record 1 of Set 3 | san patricio
# Processing Record 2 of Set 3 | kulhudhuffushi
# Processing Record 3 of Set 3 | leh
# Processing Record 4 of Set 3 | geraldton
# Processing Record 5 of Set 3 | acarau
# Processing Record 6 of Set 3 | lata
# Processing Record 7 of Set 3 | planaltina
# Processing Record 8 of Set 3 | kahului
# Processing Record 9 of Set 3 | borsec
# Processing Record 10 of Set 3 | port elizabeth
# Processing Record 11 of Set 3 | zhezkazgan
# Processing Record 12 of Set 3 | salalah
# Processing Record 13 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 3 | mutoko
# Processing Record 15 of Set 3 | saint george
# Processing Record 16 of Set 3 | kortkeros
# Processing Record 17 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 3 | tawkar
# City not found. Skipping...
# Processing Record 19 of Set 3 | pevek
# Processing Record 20 of Set 3 | grand gaube
# Processing Record 21 of Set 3 | praia da vitoria
# Processing Record 22 of Set 3 | the valley
# Processing Record 23 of Set 3 | anchorage
# Processing Record 24 of Set 3 | jambi
# Processing Record 25 of Set 3 | zhigansk
# Processing Record 26 of Set 3 | saskylakh
# Processing Record 27 of Set 3 | worms
# Processing Record 28 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 29 of Set 3 | talnakh
# Processing Record 30 of Set 3 | la ronge
# Processing Record 31 of Set 3 | itarema
# Processing Record 32 of Set 3 | aklavik
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | raudeberg
# Processing Record 35 of Set 3 | kaitangata
# Processing Record 36 of Set 3 | namibe
# Processing Record 37 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 38 of Set 3 | muroto
# Processing Record 39 of Set 3 | juan lacaze
# Processing Record 40 of Set 3 | dikson
# Processing Record 41 of Set 3 | lucapa
# Processing Record 42 of Set 3 | clyde river
# Processing Record 43 of Set 3 | khatanga
# Processing Record 44 of Set 3 | kainantu
# Processing Record 45 of Set 3 | bethel
# Processing Record 46 of Set 3 | birao
# Processing Record 47 of Set 3 | khandyga
# Processing Record 48 of Set 3 | fort nelson
# Processing Record 49 of Set 3 | cap malheureux
# Processing Record 50 of Set 3 | ciudad bolivar
# Processing Record 1 of Set 4 | suntar
# Processing Record 2 of Set 4 | tessalit
# Processing Record 3 of Set 4 | sinnamary
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | portland
# Processing Record 6 of Set 4 | khurianwala
# City not found. Skipping...
# Processing Record 7 of Set 4 | airai
# Processing Record 8 of Set 4 | chancay
# Processing Record 9 of Set 4 | qandala
# Processing Record 10 of Set 4 | sakhon nakhon
# Processing Record 11 of Set 4 | gamba
# Processing Record 12 of Set 4 | nouadhibou
# Processing Record 13 of Set 4 | puerto baquerizo moreno
# Processing Record 14 of Set 4 | mildura
# Processing Record 15 of Set 4 | kruisfontein
# Processing Record 16 of Set 4 | los llanos de aridane
# Processing Record 17 of Set 4 | katobu
# Processing Record 18 of Set 4 | ibicarai
# Processing Record 19 of Set 4 | chapleau
# Processing Record 20 of Set 4 | san quintin
# Processing Record 21 of Set 4 | tucuma
# Processing Record 22 of Set 4 | maningrida
# Processing Record 23 of Set 4 | provideniya
# Processing Record 24 of Set 4 | mao
# Processing Record 25 of Set 4 | rawson
# Processing Record 26 of Set 4 | chunoyar
# Processing Record 27 of Set 4 | pangnirtung
# Processing Record 28 of Set 4 | ak-dovurak
# Processing Record 29 of Set 4 | ceres
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | kumluca
# Processing Record 32 of Set 4 | vestmannaeyjar
# Processing Record 33 of Set 4 | kharp
# Processing Record 34 of Set 4 | roald
# Processing Record 35 of Set 4 | husavik
# Processing Record 36 of Set 4 | kirakira
# Processing Record 37 of Set 4 | severnoye
# Processing Record 38 of Set 4 | honningsvag
# Processing Record 39 of Set 4 | saldanha
# Processing Record 40 of Set 4 | buchanan
# Processing Record 41 of Set 4 | nantucket
# Processing Record 42 of Set 4 | oak ridge
# Processing Record 43 of Set 4 | sitka
# Processing Record 44 of Set 4 | trapani
# Processing Record 45 of Set 4 | kathu
# Processing Record 46 of Set 4 | taoudenni
# Processing Record 47 of Set 4 | ytre arna
# Processing Record 48 of Set 4 | dukat
# Processing Record 49 of Set 4 | mayo
# Processing Record 50 of Set 4 | bubaque
# Processing Record 1 of Set 5 | santana do acarau
# Processing Record 2 of Set 5 | lasa
# Processing Record 3 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 4 of Set 5 | saint-pierre
# Processing Record 5 of Set 5 | maanshan
# Processing Record 6 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 5 | chillicothe
# Processing Record 8 of Set 5 | berlevag
# Processing Record 9 of Set 5 | bandarbeyla
# Processing Record 10 of Set 5 | ilhabela
# Processing Record 11 of Set 5 | kralendijk
# Processing Record 12 of Set 5 | coihaique
# Processing Record 13 of Set 5 | narsaq
# Processing Record 14 of Set 5 | zlatoustovsk
# City not found. Skipping...
# Processing Record 15 of Set 5 | thabazimbi
# Processing Record 16 of Set 5 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 5 | tuzamapan
# Processing Record 18 of Set 5 | dudinka
# Processing Record 19 of Set 5 | baruun-urt
# Processing Record 20 of Set 5 | bara
# Processing Record 21 of Set 5 | morrope
# Processing Record 22 of Set 5 | mahibadhoo
# Processing Record 23 of Set 5 | coahuayana
# Processing Record 24 of Set 5 | vardo
# Processing Record 25 of Set 5 | victoria
# Processing Record 26 of Set 5 | karatuzskoye
# Processing Record 27 of Set 5 | novoaleksandrovsk
# Processing Record 28 of Set 5 | sabha
# Processing Record 29 of Set 5 | harper
# Processing Record 30 of Set 5 | moerai
# Processing Record 31 of Set 5 | wad rawah
# Processing Record 32 of Set 5 | general pico
# Processing Record 33 of Set 5 | ternate
# Processing Record 34 of Set 5 | hami
# Processing Record 35 of Set 5 | kurumkan
# Processing Record 36 of Set 5 | hobyo
# Processing Record 37 of Set 5 | gordeyevka
# Processing Record 38 of Set 5 | beaune
# Processing Record 39 of Set 5 | puerto leguizamo
# Processing Record 40 of Set 5 | bambous virieux
# Processing Record 41 of Set 5 | lebu
# Processing Record 42 of Set 5 | havre-saint-pierre
# Processing Record 43 of Set 5 | mehamn
# Processing Record 44 of Set 5 | dicabisagan
# Processing Record 45 of Set 5 | seoul
# Processing Record 46 of Set 5 | borogontsy
# Processing Record 47 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 48 of Set 5 | ust-tsilma
# Processing Record 49 of Set 5 | valparaiso
# Processing Record 50 of Set 5 | uyovu
# Processing Record 1 of Set 6 | constitucion
# Processing Record 2 of Set 6 | rodrigues alves
# Processing Record 3 of Set 6 | bonthe
# Processing Record 4 of Set 6 | lindsay
# Processing Record 5 of Set 6 | diapaga
# Processing Record 6 of Set 6 | florianopolis
# Processing Record 7 of Set 6 | katsuura
# Processing Record 8 of Set 6 | beloha
# Processing Record 9 of Set 6 | solano
# Processing Record 10 of Set 6 | manggar
# Processing Record 11 of Set 6 | ouallam
# Processing Record 12 of Set 6 | tsiroanomandidy
# Processing Record 13 of Set 6 | natitingou
# Processing Record 14 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 6 | paamiut
# Processing Record 16 of Set 6 | waterloo
# Processing Record 17 of Set 6 | kasongo-lunda
# Processing Record 18 of Set 6 | olgod
# Processing Record 19 of Set 6 | baghdad
# Processing Record 20 of Set 6 | staryy nadym
# Processing Record 21 of Set 6 | emba
# Processing Record 22 of Set 6 | nangloi jat
# Processing Record 23 of Set 6 | coolum beach
# Processing Record 24 of Set 6 | koumac
# Processing Record 25 of Set 6 | nichinan
# Processing Record 26 of Set 6 | kurdzhinovo
# Processing Record 27 of Set 6 | teguise
# Processing Record 28 of Set 6 | sines
# Processing Record 29 of Set 6 | palmerston
# Processing Record 30 of Set 6 | itaituba
# Processing Record 31 of Set 6 | cidreira
# Processing Record 32 of Set 6 | conde
# Processing Record 33 of Set 6 | half moon bay
# Processing Record 34 of Set 6 | iqaluit
# Processing Record 35 of Set 6 | soyo
# Processing Record 36 of Set 6 | atar
# Processing Record 37 of Set 6 | karratha
# Processing Record 38 of Set 6 | sika
# Processing Record 39 of Set 6 | sfantu gheorghe
# Processing Record 40 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 41 of Set 6 | pushkinskiye gory
# Processing Record 42 of Set 6 | kajaani
# Processing Record 43 of Set 6 | gorontalo
# Processing Record 44 of Set 6 | buraydah
# Processing Record 45 of Set 6 | souillac
# Processing Record 46 of Set 6 | garowe
# Processing Record 47 of Set 6 | angoche
# Processing Record 48 of Set 6 | khovu-aksy
# Processing Record 49 of Set 6 | ibra
# Processing Record 50 of Set 6 | brownwood
# Processing Record 1 of Set 7 | omutinskoye
# City not found. Skipping...
# Processing Record 2 of Set 7 | yerbogachen
# Processing Record 3 of Set 7 | panzhihua
# Processing Record 4 of Set 7 | dubbo
# Processing Record 5 of Set 7 | chifeng
# Processing Record 6 of Set 7 | harrisonburg
# Processing Record 7 of Set 7 | sug-aksy
# City not found. Skipping...
# Processing Record 8 of Set 7 | biloela
# Processing Record 9 of Set 7 | palmer
# Processing Record 10 of Set 7 | haines junction
# Processing Record 11 of Set 7 | lashio
# Processing Record 12 of Set 7 | chokurdakh
# Processing Record 13 of Set 7 | bertoua
# Processing Record 14 of Set 7 | hasaki
# Processing Record 15 of Set 7 | san cristobal
# Processing Record 16 of Set 7 | nautla
# Processing Record 17 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 18 of Set 7 | broome
# Processing Record 19 of Set 7 | vila velha
# Processing Record 20 of Set 7 | biak
# Processing Record 21 of Set 7 | bismarck
# Processing Record 22 of Set 7 | mirnyy
# Processing Record 23 of Set 7 | scottsboro
# Processing Record 24 of Set 7 | rincon
# Processing Record 25 of Set 7 | batagay
# Processing Record 26 of Set 7 | safaga
# Processing Record 27 of Set 7 | anadyr
# Processing Record 28 of Set 7 | tuatapere
# Processing Record 29 of Set 7 | caravelas
# Processing Record 30 of Set 7 | quatre cocos
# Processing Record 31 of Set 7 | yarega
# Processing Record 32 of Set 7 | ostrovnoy
# Processing Record 33 of Set 7 | ilulissat
# Processing Record 34 of Set 7 | koslan
# Processing Record 35 of Set 7 | arroyo
# Processing Record 36 of Set 7 | tabou
# Processing Record 37 of Set 7 | jalu
# Processing Record 38 of Set 7 | ovada
# Processing Record 39 of Set 7 | kalat
# Processing Record 40 of Set 7 | liverpool
# Processing Record 41 of Set 7 | jidong
# Processing Record 42 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 43 of Set 7 | minab
# Processing Record 44 of Set 7 | henties bay
# Processing Record 45 of Set 7 | norman wells
# Processing Record 46 of Set 7 | kavieng
# Processing Record 47 of Set 7 | guilin
# Processing Record 48 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 49 of Set 7 | stokmarknes
# Processing Record 50 of Set 7 | lityn
# Processing Record 1 of Set 8 | sun city west
# Processing Record 2 of Set 8 | praya
# Processing Record 3 of Set 8 | necochea
# Processing Record 4 of Set 8 | galle
# Processing Record 5 of Set 8 | solnechnyy
# Processing Record 6 of Set 8 | nizwa
# Processing Record 7 of Set 8 | mundo nuevo
# Processing Record 8 of Set 8 | khorramshahr
# Processing Record 9 of Set 8 | olenino
# Processing Record 10 of Set 8 | port hardy
# Processing Record 11 of Set 8 | camocim
# Processing Record 12 of Set 8 | sabanalarga
# Processing Record 13 of Set 8 | victor harbor
# Processing Record 14 of Set 8 | esperance
# Processing Record 15 of Set 8 | wynyard
# Processing Record 16 of Set 8 | hawalli
# Processing Record 17 of Set 8 | corinto
# Processing Record 18 of Set 8 | komsomolskiy
# Processing Record 19 of Set 8 | taltal
# Processing Record 20 of Set 8 | conceicao do araguaia
# Processing Record 21 of Set 8 | bairiki
# Processing Record 22 of Set 8 | sylvan lake
# Processing Record 23 of Set 8 | cristobal obregon
# Processing Record 24 of Set 8 | ubinskoye
# Processing Record 25 of Set 8 | chiredzi
# Processing Record 26 of Set 8 | palora
# Processing Record 27 of Set 8 | rey bouba
# Processing Record 28 of Set 8 | yulara
# Processing Record 29 of Set 8 | tawang
# Processing Record 30 of Set 8 | bay roberts
# Processing Record 31 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 32 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 8 | daulatpur
# Processing Record 35 of Set 8 | port hueneme
# Processing Record 36 of Set 8 | olafsvik
# Processing Record 37 of Set 8 | artyk
# City not found. Skipping...
# Processing Record 38 of Set 8 | lagoa
# Processing Record 39 of Set 8 | honiara
# Processing Record 40 of Set 8 | carutapera
# Processing Record 41 of Set 8 | san estanislao
# Processing Record 42 of Set 8 | domoni
# Processing Record 43 of Set 8 | sechura
# Processing Record 44 of Set 8 | kawalu
# Processing Record 45 of Set 8 | cabo san lucas
# Processing Record 46 of Set 8 | skoghall
# Processing Record 47 of Set 8 | nuuk
# Processing Record 48 of Set 8 | camapua
# Processing Record 49 of Set 8 | atbasar
# Processing Record 50 of Set 8 | malakal
# Processing Record 1 of Set 9 | belmonte
# Processing Record 2 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 9 | mount isa
# Processing Record 4 of Set 9 | thinadhoo
# Processing Record 5 of Set 9 | agirish
# Processing Record 6 of Set 9 | naze
# Processing Record 7 of Set 9 | petrivka
# Processing Record 8 of Set 9 | kuytun
# Processing Record 9 of Set 9 | sabancuy
# Processing Record 10 of Set 9 | beringovskiy
# Processing Record 11 of Set 9 | kalakamati
# Processing Record 12 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 13 of Set 9 | zabinka
# City not found. Skipping...
# Processing Record 14 of Set 9 | kalomo
# City not found. Skipping...
# Processing Record 15 of Set 9 | ust-maya
# Processing Record 16 of Set 9 | darnah
# Processing Record 17 of Set 9 | boulder city
# Processing Record 18 of Set 9 | walvis bay
# Processing Record 19 of Set 9 | samarai
# Processing Record 20 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 9 | pirgos
# Processing Record 22 of Set 9 | chardara
# Processing Record 23 of Set 9 | moussoro
# Processing Record 24 of Set 9 | westport
# Processing Record 25 of Set 9 | bayangol
# Processing Record 26 of Set 9 | jurm
# Processing Record 27 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 28 of Set 9 | chapais
# Processing Record 29 of Set 9 | lavrentiya
# Processing Record 30 of Set 9 | salta
# Processing Record 31 of Set 9 | ndende
# Processing Record 32 of Set 9 | bonfim
# Processing Record 33 of Set 9 | pakokku
# Processing Record 34 of Set 9 | meulaboh
# Processing Record 35 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 9 | polyarnyy
# Processing Record 37 of Set 9 | rabak
# Processing Record 38 of Set 9 | kokopo
# Processing Record 39 of Set 9 | matara
# Processing Record 40 of Set 9 | ilebo
# Processing Record 41 of Set 9 | port blair
# Processing Record 42 of Set 9 | nagar
# Processing Record 43 of Set 9 | kharitonovo
# Processing Record 44 of Set 9 | sambo creek
# Processing Record 45 of Set 9 | kudahuvadhoo
# Processing Record 46 of Set 9 | killybegs
# Processing Record 47 of Set 9 | gudari
# Processing Record 48 of Set 9 | tezu
# Processing Record 49 of Set 9 | lunsar
# Processing Record 50 of Set 9 | jiayuguan
# Processing Record 1 of Set 10 | pinsk
# Processing Record 2 of Set 10 | grindavik
# Processing Record 3 of Set 10 | camana
# Processing Record 4 of Set 10 | egvekinot
# Processing Record 5 of Set 10 | porto novo
# Processing Record 6 of Set 10 | ginir
# Processing Record 7 of Set 10 | cascais
# Processing Record 8 of Set 10 | athabasca
# Processing Record 9 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 10 of Set 10 | dong xoai
# Processing Record 11 of Set 10 | luohe
# Processing Record 12 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 13 of Set 10 | kloulklubed
# Processing Record 14 of Set 10 | huambo
# Processing Record 15 of Set 10 | road town
# Processing Record 16 of Set 10 | flinders
# Processing Record 17 of Set 10 | kadhan
# Processing Record 18 of Set 10 | juliaca
# Processing Record 19 of Set 10 | kisanga
# Processing Record 20 of Set 10 | alofi
# Processing Record 21 of Set 10 | padang
# Processing Record 22 of Set 10 | dolores
# Processing Record 23 of Set 10 | nanortalik
# Processing Record 24 of Set 10 | saint pete beach
# Processing Record 25 of Set 10 | aguimes
# Processing Record 26 of Set 10 | okrika
# Processing Record 27 of Set 10 | lazaro cardenas
# Processing Record 28 of Set 10 | carballo
# Processing Record 29 of Set 10 | lamin
# Processing Record 30 of Set 10 | alamosa
# Processing Record 31 of Set 10 | college
# Processing Record 32 of Set 10 | idar
# Processing Record 33 of Set 10 | kungurtug
# Processing Record 34 of Set 10 | bushehr
# Processing Record 35 of Set 10 | duiwelskloof
# Processing Record 36 of Set 10 | boyolangu
# Processing Record 37 of Set 10 | sayhat
# Processing Record 38 of Set 10 | salobrena
# Processing Record 39 of Set 10 | kisangani
# Processing Record 40 of Set 10 | chekhov
# Processing Record 41 of Set 10 | cervo
# Processing Record 42 of Set 10 | seydi
# Processing Record 43 of Set 10 | huilong
# Processing Record 44 of Set 10 | grenada
# Processing Record 45 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 10 | kem
# Processing Record 47 of Set 10 | kyzyl-suu
# Processing Record 48 of Set 10 | hervey bay
# Processing Record 49 of Set 10 | krasnoselkup
# Processing Record 50 of Set 10 | kumano
# Processing Record 1 of Set 11 | aripuana
# Processing Record 2 of Set 11 | dingle
# Processing Record 3 of Set 11 | high level
# Processing Record 4 of Set 11 | puerto escondido
# Processing Record 5 of Set 11 | singaraja
# Processing Record 6 of Set 11 | asau
# Processing Record 7 of Set 11 | anloga
# Processing Record 8 of Set 11 | nome
# Processing Record 9 of Set 11 | pulandian
# Processing Record 10 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 11 | callaway
# Processing Record 13 of Set 11 | montgomery
# Processing Record 14 of Set 11 | uk
# City not found. Skipping...
# Processing Record 15 of Set 11 | araouane
# Processing Record 16 of Set 11 | andilamena
# Processing Record 17 of Set 11 | mgandu
# Processing Record 18 of Set 11 | erzin
# Processing Record 19 of Set 11 | cayenne
# Processing Record 20 of Set 11 | roma
# Processing Record 21 of Set 11 | muros
# Processing Record 22 of Set 11 | salamiyah
# Processing Record 23 of Set 11 | forestville
# Processing Record 24 of Set 11 | kushmurun
# Processing Record 25 of Set 11 | owando
# Processing Record 26 of Set 11 | antalaha
# Processing Record 27 of Set 11 | comodoro rivadavia
# Processing Record 28 of Set 11 | tura
# Processing Record 29 of Set 11 | indiaroba
# Processing Record 30 of Set 11 | bumba
# Processing Record 31 of Set 11 | savannakhet
# Processing Record 32 of Set 11 | phangnga
# Processing Record 33 of Set 11 | adelanto
# Processing Record 34 of Set 11 | west plains
# Processing Record 35 of Set 11 | aykhal
# Processing Record 36 of Set 11 | andenes
# Processing Record 37 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 11 | strezhevoy
# Processing Record 39 of Set 11 | riyadh
# Processing Record 40 of Set 11 | ahipara
# Processing Record 41 of Set 11 | coquimbo
# Processing Record 42 of Set 11 | turukhansk
# Processing Record 43 of Set 11 | nong bua
# Processing Record 44 of Set 11 | kirkwall
# Processing Record 45 of Set 11 | bay city
# Processing Record 46 of Set 11 | goderich
# Processing Record 47 of Set 11 | sovetskiy
# Processing Record 48 of Set 11 | jiuquan
# Processing Record 49 of Set 11 | tiznit
# Processing Record 50 of Set 11 | sola
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | moa
# Processing Record 3 of Set 12 | isangel
# Processing Record 4 of Set 12 | chernyshevskiy
# Processing Record 5 of Set 12 | la crosse
# Processing Record 6 of Set 12 | kenai
# Processing Record 7 of Set 12 | puerto madero
# Processing Record 8 of Set 12 | chekalin
# Processing Record 9 of Set 12 | rehoboth
# Processing Record 10 of Set 12 | bakchar
# Processing Record 11 of Set 12 | hofn
# Processing Record 12 of Set 12 | melville
# Processing Record 13 of Set 12 | merta
# Processing Record 14 of Set 12 | port augusta
# Processing Record 15 of Set 12 | gobabis
# Processing Record 16 of Set 12 | umm lajj
# Processing Record 17 of Set 12 | yaya
# Processing Record 18 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 12 | changji
# Processing Record 20 of Set 12 | ybycui
# Processing Record 21 of Set 12 | pimentel
# Processing Record 22 of Set 12 | dondo
# Processing Record 23 of Set 12 | barcelos
# Processing Record 24 of Set 12 | hede
# Processing Record 25 of Set 12 | ulladulla
# Processing Record 26 of Set 12 | jumla
# Processing Record 27 of Set 12 | mana
# Processing Record 28 of Set 12 | yekaterinogradskaya
# Processing Record 29 of Set 12 | kota kinabalu
# Processing Record 30 of Set 12 | banjar
# Processing Record 31 of Set 12 | marzuq
# Processing Record 32 of Set 12 | semirom
# Processing Record 33 of Set 12 | kulunda
# Processing Record 34 of Set 12 | abrau-dyurso
# Processing Record 35 of Set 12 | avera
# Processing Record 36 of Set 12 | talara
# Processing Record 37 of Set 12 | abu samrah
# Processing Record 38 of Set 12 | pasighat
# Processing Record 39 of Set 12 | ola
# Processing Record 40 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 12 | eureka
# Processing Record 42 of Set 12 | port-gentil
# Processing Record 43 of Set 12 | clinton
# Processing Record 44 of Set 12 | sibolga
# Processing Record 45 of Set 12 | korla
# Processing Record 46 of Set 12 | nyimba
# Processing Record 47 of Set 12 | svetlaya
# Processing Record 48 of Set 12 | olinda
# Processing Record 49 of Set 12 | awbari
# Processing Record 50 of Set 12 | codrington
# Processing Record 1 of Set 13 | longyan
# Processing Record 2 of Set 13 | vestmanna
# Processing Record 3 of Set 13 | umm kaddadah
# Processing Record 4 of Set 13 | san carlos de bariloche
# Processing Record 5 of Set 13 | north bend
# Processing Record 6 of Set 13 | dunedin
# Processing Record 7 of Set 13 | mokhsogollokh
# Processing Record 8 of Set 13 | upata
# Processing Record 9 of Set 13 | boddam
# Processing Record 10 of Set 13 | svetlyy
# Processing Record 11 of Set 13 | shache
# Processing Record 12 of Set 13 | morant bay
# Processing Record 13 of Set 13 | praia
# Processing Record 14 of Set 13 | velasco ibarra
# Processing Record 15 of Set 13 | mardin
# Processing Record 16 of Set 13 | oranjemund
# Processing Record 17 of Set 13 | faya
# Processing Record 18 of Set 13 | saint-joseph
# Processing Record 19 of Set 13 | sidi ali
# Processing Record 20 of Set 13 | poso
# Processing Record 21 of Set 13 | pedernales
# Processing Record 22 of Set 13 | wanning
# Processing Record 23 of Set 13 | touros
# Processing Record 24 of Set 13 | umm bab
# Processing Record 25 of Set 13 | spring valley
# Processing Record 26 of Set 13 | montepuez
# Processing Record 27 of Set 13 | gornopravdinsk
# Processing Record 28 of Set 13 | utraula
# Processing Record 29 of Set 13 | kieta
# Processing Record 30 of Set 13 | kavaratti
# Processing Record 31 of Set 13 | great yarmouth
# Processing Record 32 of Set 13 | sabak
# Processing Record 33 of Set 13 | peniche
# Processing Record 34 of Set 13 | aguia branca
# Processing Record 35 of Set 13 | ucluelet
# Processing Record 36 of Set 13 | prince rupert
# Processing Record 37 of Set 13 | belen
# Processing Record 38 of Set 13 | verkhnevilyuysk
# Processing Record 39 of Set 13 | mragowo
# Processing Record 40 of Set 13 | torbay
# Processing Record 41 of Set 13 | merauke
# Processing Record 42 of Set 13 | pomezia
# Processing Record 43 of Set 13 | decatur
# Processing Record 44 of Set 13 | nishihara
# Processing Record 45 of Set 13 | krasnoarmeysk
# Processing Record 46 of Set 13 | sorland
# Processing Record 47 of Set 13 | sultanpur
# Processing Record 48 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 49 of Set 13 | uruzgan
# Processing Record 50 of Set 13 | oistins
# Processing Record 1 of Set 14 | ulaangom
# Processing Record 2 of Set 14 | sulangan
# Processing Record 3 of Set 14 | margate
# Processing Record 4 of Set 14 | astoria
# Processing Record 5 of Set 14 | kutum
# Processing Record 6 of Set 14 | snasa
# Processing Record 7 of Set 14 | nyuksenitsa
# Processing Record 8 of Set 14 | xichang
# Processing Record 9 of Set 14 | sorong
# Processing Record 10 of Set 14 | itaueira
# Processing Record 11 of Set 14 | yian
# City not found. Skipping...
# Processing Record 12 of Set 14 | burns lake
# Processing Record 13 of Set 14 | craig
# Processing Record 14 of Set 14 | upington
# Processing Record 15 of Set 14 | sande
# Processing Record 16 of Set 14 | vuktyl
# Processing Record 17 of Set 14 | rio gallegos
# Processing Record 18 of Set 14 | flin flon
# Processing Record 19 of Set 14 | moss point
# Processing Record 20 of Set 14 | ayagoz
# Processing Record 21 of Set 14 | damietta
# Processing Record 22 of Set 14 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 14 | lehigh acres
# Processing Record 24 of Set 14 | tigil
# Processing Record 25 of Set 14 | kotido
# Processing Record 26 of Set 14 | mezen
# Processing Record 27 of Set 14 | marion
# Processing Record 28 of Set 14 | gushikawa
# Processing Record 29 of Set 14 | manono
# Processing Record 30 of Set 14 | asfi
# Processing Record 31 of Set 14 | soltsy
# Processing Record 32 of Set 14 | sarankhola
# Processing Record 33 of Set 14 | nelspruit
# Processing Record 34 of Set 14 | bozeman
# Processing Record 35 of Set 14 | natal
# Processing Record 36 of Set 14 | chumikan
# Processing Record 37 of Set 14 | aksarka
# Processing Record 38 of Set 14 | kabinda
# Processing Record 39 of Set 14 | ambilobe
# Processing Record 40 of Set 14 | buala
# Processing Record 41 of Set 14 | tautira
# Processing Record 42 of Set 14 | vostok
# Processing Record 43 of Set 14 | san lorenzo
# Processing Record 44 of Set 14 | marathon
# Processing Record 45 of Set 14 | yar-sale
# Processing Record 46 of Set 14 | port keats
# Processing Record 47 of Set 14 | paoua
# Processing Record 48 of Set 14 | japura
# Processing Record 49 of Set 14 | filingue
# Processing Record 50 of Set 14 | okha
# Processing Record 1 of Set 15 | rocha
# Processing Record 2 of Set 15 | russell
# Processing Record 3 of Set 15 | kosh-agach
# Processing Record 4 of Set 15 | nadym
# Processing Record 5 of Set 15 | kontagora
# Processing Record 6 of Set 15 | hokitika
# Processing Record 7 of Set 15 | saquarema
# Processing Record 8 of Set 15 | lumphat
# Processing Record 9 of Set 15 | blairmore
# Processing Record 10 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 15 | paso de patria
# Processing Record 13 of Set 15 | belaya gora
# Processing Record 14 of Set 15 | bac can
# City not found. Skipping...
# Processing Record 15 of Set 15 | kiunga
# Processing Record 16 of Set 15 | kon tum
# Processing Record 17 of Set 15 | tomatlan
# Processing Record 18 of Set 15 | tashara
# Processing Record 19 of Set 15 | shirokiy
# Processing Record 20 of Set 15 | grenville
# Processing Record 21 of Set 15 | homer
# Processing Record 22 of Set 15 | sandpoint
# Processing Record 23 of Set 15 | sur
# Processing Record 24 of Set 15 | pousat
# City not found. Skipping...
# Processing Record 25 of Set 15 | manzil jamil
# City not found. Skipping...
# Processing Record 26 of Set 15 | kerema
# Processing Record 27 of Set 15 | bobonong
# City not found. Skipping...
# Processing Record 28 of Set 15 | miri
# Processing Record 29 of Set 15 | luanda
# Processing Record 30 of Set 15 | erdenet
# Processing Record 31 of Set 15 | tramandai
# Processing Record 32 of Set 15 | male
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Ushuaia      AR -54.8000  -68.3000     46.02        70          40
# 1           Castro      BR -24.7911  -50.0119     74.73        66          88
# 2            Bluff      NZ -46.6000  168.3333     47.35        88          63
# 3          Te Anau      NZ -45.4167  167.7167     44.80        94          39
# 4      Spring Hill      US  28.4769  -82.5255     86.99        53          20
# 5          Mataura      NZ -46.1927  168.8643     40.86        99          17
# 6  Port Hawkesbury      CA  45.6169  -61.3485     48.04        79          75
# 7        Cape Town      ZA -33.9258   18.4232     62.11        86           0
# 8        Roebourne      AU -20.7833  117.1333     72.34        84         100
# 9        Busselton      AU -33.6500  115.3333     57.45        74          84
#
#    Wind Speed Current Description
# 0       37.98    scattered clouds
# 1        6.26     overcast clouds
# 2        4.70       broken clouds
# 3        1.01    scattered clouds
# 4       13.80          few clouds
# 5        1.66          few clouds
# 6       13.80       broken clouds
# 7       11.50           clear sky
# 8        7.29          light rain
# 9        5.68       broken clouds

# %%
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label='City_ID')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_44880\3782751744.py in <module>
#       1 output_data_file = "Weather_Database/WeatherPy_Database.csv"
# ----> 2 city_data_df.to_csv(output_data_file, index_label='City_ID')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     241             errors=self.errors,
#     242             compression=self.compression,
# --> 243             storage_options=self.storage_options,
#     244         ) as handles:
#     245
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Weather_Database/WeatherPy_Database.csv'
